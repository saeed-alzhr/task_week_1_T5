# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %%
import pandas as pd

# %% [markdown]
# ### Read the dataset

# %%
df=pd.read_csv("Task (1) Dataset.csv")
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df.isnull().sum().head(16)
# Out:
# Time                          0
# Day_of_week                   0
# Age_band_of_driver            0
# Sex_of_driver                 0
# Educational_level           741
# Vehicle_driver_relation     579
# Driving_experience          829
# Type_of_vehicle             950
# Owner_of_vehicle            482
# Service_year_of_vehicle    3928
# Defect_of_vehicle          4427
# Area_accident_occured       239
# Lanes_or_Medians            385
# Road_allignment             142
# Types_of_Junction           887
# Road_surface_type           172
# dtype: int64

# %%
df['Driving_experience'].sample()
# Out:
# 4918    5-10yr
# Name: Driving_experience, dtype: object

# %% [markdown]
# **these are columns should be handeled**
# - Driving_experience:any missing value with 5-10yr
# - Lanes_or_Medians: any missing value with other
# - Road_surface_type:any missing value with  Asphalt roads

# %%
df.isnull().sum().tail(16)
# Out:
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
# all of these columns could not be filled or not importent 
df.drop('Educational_level', axis=1, inplace=True)
df.drop('Vehicle_driver_relation', axis=1, inplace=True)
df.drop('Type_of_vehicle', axis=1, inplace=True)
df.drop('Owner_of_vehicle', axis=1, inplace=True)
df.drop('Service_year_of_vehicle', axis=1, inplace=True)
df.drop('Defect_of_vehicle', axis=1, inplace=True)
df.drop('Area_accident_occured', axis=1, inplace=True)
df.drop('Road_allignment', axis=1, inplace=True)
df.drop('Types_of_Junction', axis=1, inplace=True)
df.drop('Type_of_collision', axis=1, inplace=True)
df.drop('Vehicle_movement', axis=1, inplace=True)
df.drop('Work_of_casuality', axis=1, inplace=True)
df.drop('Fitness_of_casuality', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Driving_experience             829
# Lanes_or_Medians               385
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
df['Road_surface_type'].fillna("Asphalt roads",inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Driving_experience             829
# Lanes_or_Medians               385
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# Accident_severity                0
# dtype: int64

# %%
df['Lanes_or_Medians'].fillna("other",inplace=True)

# %%
df['Driving_experience'].fillna("5-10yr",inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Driving_experience             0
# Lanes_or_Medians               0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience                                  Lanes_or_Medians  \
# 0                  1-2yr                                             other
# 1             Above 10yr                                 Undivided Two way
# ...

# %%
df.replace("NaN",None,inplace=True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience                                  Lanes_or_Medians  \
# 0                  1-2yr                                             other
# 1             Above 10yr                                 Undivided Two way
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Driving_experience                0
# Lanes_or_Medians                  0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Casualty_class                 4443
# Sex_of_casualty                4443
# Age_band_of_casualty           4443
# Casualty_severity              4443
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 5      14:15:00      Friday              31-50          Male
# 6      17:30:00   Wednesday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12305   7:10:00      Friday              18-30          Male
# 12309   9:05:00      Friday              31-50        Female
# 12310   9:05:00      Friday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience                                  Lanes_or_Medians  \
# 2                  1-2yr                                             other
# 3                 5-10yr                                             other
# ...

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Driving_experience             0
# Lanes_or_Medians               0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ### Correct any inconsistent data entries.

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Driving_experience             object
# Lanes_or_Medians               object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# Pedestrian_movement            object
# Cause_of_accident              object
# Accident_severity              object
# dtype: object

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.corr
# Out:
# <bound method DataFrame.corr of            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 5      14:15:00      Friday              31-50          Male
# 6      17:30:00   Wednesday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12305   7:10:00      Friday              18-30          Male
# 12309   9:05:00      Friday              31-50        Female
# 12310   9:05:00      Friday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12315  13:55:00      Sunday              18-30          Male
#
#       Driving_experience                                  Lanes_or_Medians  \
# 2                  1-2yr                                             other
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df['Age_band_of_driver'])
plt.title('Age oo driver Distribution')
plt.xlabel('age')
plt.show()

# %% [markdown]
# **we can see that most of the acident happen to pepole in there youth**

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.relplot(data=df, x="Age_band_of_driver", y="Accident_severity",kind="line")

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.displot(df, x="Age_band_of_driver",hue="Accident_severity")

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# -  There is a relationship between the age of the person who was injured and the severity of the injury
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
# - the younger the person the more sever the injury be
